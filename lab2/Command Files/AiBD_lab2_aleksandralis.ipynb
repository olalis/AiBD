# %% [markdown]
# ## Analiza i bazy danych
# ### Laboratorium21
# Aleksanrda Lis
# grupa: 2a
# numer indeksu: 400639

# %%
import pandas as pd

# %% [markdown]
# #### Zadanie 1:

# %%
data = pd.read_csv('../Original Data/drinks.csv')
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
data.to_csv('../Analysis Data/drinks_changed.csv')
